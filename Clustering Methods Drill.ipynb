# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.datasets.samples_generator import make_blobs
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA
from sklearn.metrics import recall_score

from sklearn.cluster import MeanShift, estimate_bandwidth
from sklearn.cluster import SpectralClustering
from sklearn.cluster import AffinityPropagation
from sklearn import metrics

from itertools import cycle

# %%
def get_blobs(coordinates):
    # The coordinates of the centers of our blobs.
    centers = coordinates

    # Make 10,000 rows worth of data with two features representing three
    # clusters, each having a standard deviation of 1.
    X, y = make_blobs(
        n_samples=10000,
        centers=centers,
        cluster_std=1,
        n_features=2,
        random_state=42)

    plt.scatter(X[:, 0], X[:, 1], c=y)
    plt.show()

    #Divide into training and test sets.
    X_train, X_test, y_train, y_test = train_test_split(
        X,
        y,
        test_size=0.9,
        random_state=42)

    X_pca = PCA(2).fit_transform(X_train)

# %% [markdown]
# # K-means

# %%
def k_means(blobs,num_clusters):
    # Calculate predicted values.
    y_pred = KMeans(n_clusters=num_clusters, random_state=42).fit_predict(X_pca)
    estimator = KMeans(n_clusters=num_clusters, random_state=42).fit(X_pca)
    centers = estimator.cluster_centers_

    # Plot the solution.
    plt.scatter(X_pca[:, 0], X_pca[:, 1], c = y_pred, cmap='viridis')
    plt.scatter(centers[:, 0], centers[:, 1], c='r', s=200, alpha=0.5);
    plt.title('K-Means Clusters: k = {}'.format(num_clusters))
    plt.show()

    # Check the solution against the data.
    #print('Recall score: {}\n'.format(recall_score(y_train, y_pred, average = 'micro')))
    print('Comparing k-means clusters against the data:')
    print(pd.crosstab(y_pred, y_train))

# %% [markdown]
# ### More Blobs

# %%
centers = ([[2, 2], [-3, -2], [2, -2], [4, 0], [-1, -2], [-3, -5]])

    # Make 10,000 rows worth of data with two features representing three
    # clusters, each having a standard deviation of 1.
X, y = make_blobs(
        n_samples=10000,
        centers=centers,
        cluster_std=1,
        n_features=2,
        random_state=42)

plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

    #Divide into training and test sets.
X_train, X_test, y_train, y_test = train_test_split(
        X,
        y,
        test_size=0.9,
        random_state=42)

X_pca = PCA(2).fit_transform(X_train)
          
# Calculate predicted values.
y_pred = KMeans(n_clusters=6, random_state=42).fit_predict(X_pca)
estimator = KMeans(n_clusters=6, random_state=42).fit(X_pca)
centers = estimator.cluster_centers_

    # Plot the solution.
plt.scatter(X_pca[:, 0], X_pca[:, 1], c = y_pred, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='r', s=200, alpha=0.5);
plt.title('K-Means Clusters: k = 6')
plt.show()

    # Check the solution against the data.
    #print('Recall score: {}\n'.format(recall_score(y_train, y_pred, average = 'micro')))
print('Comparing k-means clusters against the data:')
print(pd.crosstab(y_pred, y_train))
# Out:
# Comparing k-means clusters against the data:
# col_0    0    1    2    3    4    5
# row_0
# 0      165    0    1   18    1    0
# 1        0  147    1    0   37    5
# 2       11    0    8  134    0    0
# 3        0   24    0    0    6  146
# 4        0   15   21    1  118    2
# 5        0    0  120   16    3    0

# %% [markdown]
# ### Fewer Blobs

# %%
centers = ([[2,2],[-2,-2]])

    # Make 10,000 rows worth of data with two features representing three
    # clusters, each having a standard deviation of 1.
X, y = make_blobs(
        n_samples=10000,
        centers=centers,
        cluster_std=1,
        n_features=2,
        random_state=42)

plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

    #Divide into training and test sets.
X_train, X_test, y_train, y_test = train_test_split(
        X,
        y,
        test_size=0.9,
        random_state=42)

X_pca = PCA(2).fit_transform(X_train)
          
# Calculate predicted values.
y_pred = KMeans(n_clusters=2, random_state=42).fit_predict(X_pca)
estimator = KMeans(n_clusters=2, random_state=42).fit(X_pca)
centers = estimator.cluster_centers_

    # Plot the solution.
plt.scatter(X_pca[:, 0], X_pca[:, 1], c = y_pred, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='r', s=200, alpha=0.5);
plt.title('K-Means Clusters: k = 2')
plt.show()

    # Check the solution against the data.
    #print('Recall score: {}\n'.format(recall_score(y_train, y_pred, average = 'micro')))
print('Comparing k-means clusters against the data:')
print(pd.crosstab(y_pred, y_train))
# Out:
# Comparing k-means clusters against the data:
# col_0    0    1
# row_0
# 0      512    3
# 1        0  485

# %% [markdown]
# ### Far Away Blobs

# %%
centers = ([[10, 2], [-3, -10], [7, -7], [0, 0], [-1, 9], [-9, -2]])

    # Make 10,000 rows worth of data with two features representing three
    # clusters, each having a standard deviation of 1.
X, y = make_blobs(
        n_samples=10000,
        centers=centers,
        cluster_std=1,
        n_features=2,
        random_state=42)

plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

    #Divide into training and test sets.
X_train, X_test, y_train, y_test = train_test_split(
        X,
        y,
        test_size=0.9,
        random_state=42)

X_pca = PCA(2).fit_transform(X_train)
          
# Calculate predicted values.
y_pred = KMeans(n_clusters=6, random_state=42).fit_predict(X_pca)
estimator = KMeans(n_clusters=6, random_state=42).fit(X_pca)
centers = estimator.cluster_centers_

    # Plot the solution.
plt.scatter(X_pca[:, 0], X_pca[:, 1], c = y_pred, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='r', s=200, alpha=0.5);
plt.title('K-Means Clusters: k = 6')
plt.show()

    # Check the solution against the data.
    #print('Recall score: {}\n'.format(recall_score(y_train, y_pred, average = 'micro')))
print('Comparing k-means clusters against the data:')
print(pd.crosstab(y_pred, y_train))
# Out:
# Comparing k-means clusters against the data:
# col_0    0    1    2    3    4    5
# row_0
# 0      176    0    0    0    0    0
# 1        0    0    0  169    0    0
# 2        0    0    0    0  165    0
# 3        0  186    0    0    0    0
# 4        0    0    0    0    0  153
# 5        0    0  151    0    0    0

# %% [markdown]
# - We see that when the blobs spaced apart, kmeans does an excellent job of partitioning the data, however when the data groups are not so distinct, the algorithm is not as exact in its predictions.

# %% [markdown]
# # Mean Shift

# %%
def mean_shift(blobs):
    # Here we set the bandwidth. This function automatically derives a bandwidth
    # number based on an inspection of the distances among points in the data.
    bandwidth = estimate_bandwidth(X_train, quantile=0.2, n_samples=500)

    # Declare and fit the model.
    ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
    ms.fit(X_train)

    # Extract cluster assignments for each data point.
    labels = ms.labels_

    # Coordinates of the cluster centers.
    cluster_centers = ms.cluster_centers_

    # Count our clusters.
    n_clusters_ = len(np.unique(labels))

    plt.scatter(X_train[:, 0], X_train[:, 1], c=labels)
    plt.show()

    #print('Recall score: {}\n'.format(recall_score(y_train, y_pred, average = 'micro')))
    print("Number of estimated clusters: {}".format(n_clusters_))

    print('Comparing the assigned categories to the ones in the data:')
    print(pd.crosstab(y_train,labels))

# %% [markdown]
# ### More Blobs

# %%
blobs = get_blobs([[2, 2], [-3, -2], [2, -2], [4, 0], [-1, -2], [-3, -5]])

mean_shift(blobs)
# Out:
# Number of estimated clusters: 3
# Comparing the assigned categories to the ones in the data:
# col_0    0    1    2
# row_0
# 0        0  173    3
# 1      184    0    2
# 2        2   26  123
# 3        0  164    5
# 4      110    0   55
# 5      152    0    1

# %% [markdown]
# ### Fewer Blobs

# %%
blobs = get_blobs([[2, 2], [-2, -2]])

mean_shift(blobs)
# Out:
# Number of estimated clusters: 2
# Comparing the assigned categories to the ones in the data:
# col_0    0    1
# row_0
# 0      512    0
# 1        2  486

# %% [markdown]
# ### Far Away Blobs

# %%
blobs = get_blobs([[10, 2], [-3, -10], [7, -7], [0, 0], [-1, 9], [-9, -2]])

mean_shift(blobs)
# Out:
# Number of estimated clusters: 3
# Comparing the assigned categories to the ones in the data:
# col_0    0    1    2
# row_0
# 0        0  176    0
# 1      186    0    0
# 2        0  151    0
# 3       38   25  106
# 4        0    0  165
# 5      153    0    0

# %% [markdown]
# - By the mean shift algorithm we see the same conflicts as the kmeans method when the data is not seperated, and further we see that when the number of data groups increase, the mean shift algorithm under estimates the number of actual clusters.

# %% [markdown]
# # Spectral Clustering

# %%
def spec_cluster(blobs, num_cluster):
    # We know we're looking for three clusters.
    n_clusters=num_cluster

# Declare and fit the model.
    sc = SpectralClustering(n_clusters=n_clusters)
    sc.fit(X_train)

#Predicted clusters.
    predict=sc.fit_predict(X_train)

#Graph results.
    plt.scatter(X_train[:, 0], X_train[:, 1], c=predict)
    plt.show()

#print('Recall score: {}\n'.format(recall_score(y_train, predict, average = 'micro')))
    print('Comparing the assigned categories to the ones in the data:')
    print(pd.crosstab(y_train,predict))

# %% [markdown]
# ### More Blobs

# %%
blobs = get_blobs([[2, 2], [-3, -2], [2, -2], [4, 0], [-1, -2], [-3, -5]])

spec_cluster(blobs,6)
# Out:
# Comparing the assigned categories to the ones in the data:
# col_0    0    1    2    3    4    5
# row_0
# 0        0    1    0   11  164    0
# 1        0   25   11    0    0  150
# 2      125   18    0    6    2    0
# 3       20    1    0  128   20    0
# 4        4  138    4    0    1   18
# 5        0    2  138    0    0   13

# %% [markdown]
# ### Fewer Blobs

# %%
blobs = get_blobs([[2, 2], [-2, -2]])

spec_cluster(blobs,2)
# Out:
# Comparing the assigned categories to the ones in the data:
# col_0    0    1
# row_0
# 0        0  176
# 1      186    0
# 2       21  130
# 3        1  168
# 4      161    4
# 5      153    0

# %% [markdown]
# ### Far Away Blobs

# %%
blobs = get_blobs([[10, 2], [-3, -10], [7, -7], [0, 0], [-1, 9], [-9, -2]])

spec_cluster(blobs,6)
# Out:
# Comparing the assigned categories to the ones in the data:
# col_0    0    1    2    3    4    5
# row_0
# 0        0    0    0    0    0  176
# 1      186    0    0    0    0    0
# 2        0  151    0    0    0    0
# 3        0    0  169    0    0    0
# 4        0    0    0    0  165    0
# 5        0    0    0  153    0    0

# %% [markdown]
# - Thus far spectral cluster has shown the most accurate representations on this data set. In the data grouping case where kmeans and mean shift found trouble, the spectral clustering algorithm was able to parse the 6 groups even when they were mostly megered together without a spatial boundary.

# %% [markdown]
# # Affiniy Propogation

# %%
def aff_prop(blobs):
    # Declare the model and fit it in one statement.
    # Note that you can provide arguments to the model, but we didn't.
    af = AffinityPropagation().fit(X_train)

    # Pull the number of clusters and cluster assignments for each data point.
    cluster_centers_indices = af.cluster_centers_indices_
    n_clusters_ = len(cluster_centers_indices)
    labels = af.labels_

    plt.figure(1)
    plt.clf()

    # Cycle through each cluster and graph them with a center point for the
    # exemplar and lines from the exemplar to each data point in the cluster.
    colors = cycle('bgrcmykbgrcmykbgrcmykbgrcmyk')
    for k, col in zip(range(n_clusters_), colors):
        class_members = labels == k
        cluster_center = X_train[cluster_centers_indices[k]]
        plt.plot(X_train[class_members, 0], X_train[class_members, 1], col + '.')
        plt.plot(cluster_center[0],
                 cluster_center[1],
                 'o',
                 markerfacecolor=col,
                 markeredgecolor='k')
        for x in X_train[class_members]:
            plt.plot([cluster_center[0], x[0]], [cluster_center[1], x[1]], col)

    plt.title('Estimated number of clusters: {}'.format(n_clusters_))
    plt.show()

# %% [markdown]
# ### More Blobs

# %%
blobs = get_blobs([[2, 2], [-3, -2], [2, -2], [4, 0], [-1, -2], [-3, -5]])

aff_prop(blobs)

# %% [markdown]
# ### Fewer Blobs

# %%
blobs = get_blobs([[2, 2], [-2, -2]])

aff_prop(blobs)

# %% [markdown]
# ### Far Away Blobs

# %%
blobs = get_blobs([[10, 2], [-3, -10], [7, -7], [0, 0], [-1, 9], [-9, -2]])

aff_prop(blobs)

# %% [markdown]
# - The affinity algorithm seems to consistently over estimate the number of groups present. I will have to look further into the characteristics of this method to see if there are any hyperparameters that may help focus the algorithm's classifications.
